# %%
# !pip install mmcv-full

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git
# Out:
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 21083, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 21083 (delta 13), reused 42 (delta 5), pack-reused 21016
# Receiving objects: 100% (21083/21083), 24.83 MiB | 24.59 MiB/s, done.
# Resolving deltas: 100% (14708/14708), done.

# %%
# %cd mmdetection
# Out:
# /content/mmdetection/mmdetection/mmdetection

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating mmdet.egg-info
# writing mmdet.egg-info/PKG-INFO
# writing dependency_links to mmdet.egg-info/dependency_links.txt
# writing requirements to mmdet.egg-info/requires.txt
# writing top-level names to mmdet.egg-info/top_level.txt
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...
# adding license file 'LICENSE'
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mmdet
# copying mmdet/__init__.py -> build/lib/mmdet
# copying mmdet/version.py -> build/lib/mmdet
# creating build/lib/mmdet/datasets
# copying mmdet/datasets/__init__.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/deepfashion.py -> build/lib/mmdet/datasets
# copying mmdet/datasets/custom.py -> build/lib/mmdet/datasets
# ...

# %%
# !ls
# Out:
# build	      docker	   mmdet	    README_zh-CN.md   setup.py
# CITATION.cff  docs	   mmdet.egg-info   requirements      tests
# configs       docs_zh-CN   model-index.yml  requirements.txt  tools
# demo	      LICENSE	   pytest.ini	    resources
# dist	      MANIFEST.in  README.md	    setup.cfg

# %%
# !mkdir checkpoints

# %%
# !ls
# Out:
# build	      demo    docs_zh-CN   mmdet.egg-info   README_zh-CN.md   setup.cfg
# checkpoints   dist    LICENSE	   model-index.yml  requirements      setup.py
# CITATION.cff  docker  MANIFEST.in  pytest.ini	    requirements.txt  tests
# configs       docs    mmdet	   README.md	    resources	      tools

# %%
#https://github.com/open-mmlab/mmdetection/tree/master/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py 해당 파일 다운로드

# %%
# !wget -O /content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth #해당 주소에 있는 것을 해당 위치의 해당 이름으로 받아옴
# Out:
# --2021-09-29 03:26:12--  https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 47.252.96.35
# Connecting to download.openmmlab.com (download.openmmlab.com)|47.252.96.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167287506 (160M) [application/octet-stream]
# Saving to: ‘/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’
#
# /content/mmdetectio 100%[===================>] 159.54M  9.28MB/s    in 18s
#
# 2021-09-29 03:26:31 (8.79 MB/s) - ‘/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’ saved [167287506/167287506]

# %%
# !ls checkpoints

# %%
#https://github.com/open-mmlab/mmdetection/tree/master/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py

# %%
# !wget /content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco.py https://github.com/open-mmlab/mmdetection/tree/master/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py
# Out:
# /content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco.py: Scheme missing.
# --2021-09-29 03:29:37--  https://github.com/open-mmlab/mmdetection/tree/master/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/open-mmlab/mmdetection/blob/master/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py [following]
# --2021-09-29 03:29:37--  https://github.com/open-mmlab/mmdetection/blob/master/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘faster_rcnn_r50_fpn_1x_coco.py’
#
# faster_rcnn_r50_fpn     [ <=>                ] 143.33K  --.-KB/s    in 0.08s
#
# ...

# %%
# !ls ./checkpoints

# %%
config_file = '/content/mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/content/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# %%
from mmdet.apis import init_detector, inference_detector #런타임을 다시시작해야함

# %%
model = init_detector(config=config_file, checkpoint=checkpoint_file)
# Out:
# /usr/local/lib/python3.7/dist-packages/mmdet-2.17.0-py3.7.egg/mmdet/core/anchor/builder.py:17: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '
# Use load_from_local loader

# %%
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check MMDetection installation
import mmdet
print(mmdet.__version__)

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())
# Out:
# 1.9.0+cu102 True
# 2.17.0
# 11.1
# GCC 7.5

# %%
# !ls -al mmdetection/checkpoints/
# Out:
# total 163380
# drwxr-xr-x  2 root root      4096 Sep 29 03:15 .
# drwxr-xr-x 20 root root      4096 Sep 29 03:22 ..
# -rw-r--r--  1 root root 167287506 Aug 28  2020 faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth

# %%
# %cd mmdetection/
img = 'demo/demo.jpg'
result = inference_detector(model, img)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/mmdet-2.17.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /usr/local/lib/python3.7/dist-packages/mmdet-2.17.0-py3.7.egg/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '

# %%
type(result)
# Out:
# list

# %%
len(result) #80개를 디텍트 한 것이 아니라 검출할 수 있는 클래스가 80개라서 80개에 대해서 확률을 추출했다는 의미
# Out:
# 80

# %%
result[:5] #디텍트가 된 것은 정보가 들어가 있다.
# Out:
# [array([[3.75348572e+02, 1.19171005e+02, 3.81950867e+02, 1.34460617e+02,
#          1.35454327e-01],
#         [5.32362000e+02, 1.09554726e+02, 5.40526550e+02, 1.25222633e+02,
#          8.88783410e-02],
#         [3.61124298e+02, 1.09049202e+02, 3.68625610e+02, 1.22483063e+02,
#          7.20723346e-02]], dtype=float32),
#  array([], shape=(0, 5), dtype=float32),
#  array([[6.09650024e+02, 1.13805893e+02, 6.34511658e+02, 1.36951904e+02,
#          9.88766134e-01],
#         [4.81773712e+02, 1.10480980e+02, 5.22459717e+02, 1.30407104e+02,
#          9.87157285e-01],
#         [1.01822114e+00, 1.12144730e+02, 6.04374733e+01, 1.44173752e+02,
#          9.83206093e-01],
#         [2.94623718e+02, 1.17035240e+02, 3.78022705e+02, 1.50550873e+02,
#          9.71326768e-01],
#         [3.96328979e+02, 1.11203323e+02, 4.32490540e+02, 1.32729263e+02,
#          9.67802167e-01],
#         [5.90976257e+02, 1.10802658e+02, 6.15401794e+02, 1.26493553e+02,
#          9.59414959e-01],
# ...

# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
show_result_pyplot(model, img, result, score_thr=0.6)
#result마다 각각의 클래스이고 해당 클래스에 해당하는 개수와 각각의 확률이 나온다. 
#모델을 통과해서 물체를검출해준다. score_thr이 높을수록 적게 검출
